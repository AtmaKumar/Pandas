# %%
import pandas as pd

# %%
data=pd.read_csv('framingham.csv')

# %%
data
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
# 4238     1   40        3.0              0         0.0     0.0
# 4239     0   39        3.0              1        30.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %%
data.head()
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39        4.0              0         0.0     0.0                0
# 1     0   46        2.0              0         0.0     0.0                0
# 2     1   48        1.0              1        20.0     0.0                0
# 3     0   61        3.0              1        30.0     0.0                0
# 4     0   46        3.0              1        23.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
# 2             0         0    245.0  127.5   80.0  25.34       75.0     70.0
# 3             1         0    225.0  150.0   95.0  28.58       65.0    103.0
# 4             0         0    285.0  130.0   84.0  23.10       85.0     85.0
#
#    TenYearCHD
# 0           0
# 1           0
# ...

# %%
data.head(10)
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39        4.0              0         0.0     0.0                0
# 1     0   46        2.0              0         0.0     0.0                0
# 2     1   48        1.0              1        20.0     0.0                0
# 3     0   61        3.0              1        30.0     0.0                0
# 4     0   46        3.0              1        23.0     0.0                0
# 5     0   43        2.0              0         0.0     0.0                0
# 6     0   63        1.0              0         0.0     0.0                0
# 7     0   45        2.0              1        20.0     0.0                0
# 8     1   52        1.0              0         0.0     0.0                0
# 9     1   43        1.0              1        30.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# ...

# %%
data.head(2)
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39        4.0              0         0.0     0.0                0
# 1     0   46        2.0              0         0.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
#
#    TenYearCHD
# 0           0
# 1           0

# %%
data.tail()
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
# 4238     1   40        3.0              0         0.0     0.0
# 4239     0   39        3.0              1        30.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 4235                0             0         0    248.0  131.0   72.0  22.00
# 4236                0             0         0    210.0  126.5   87.0  19.16
# 4237                0             0         0    269.0  133.5   83.0  21.47
# 4238                0             1         0    185.0  141.0   98.0  25.60
# 4239                0             0         0    196.0  133.0   86.0  20.91
#
#       heartRate  glucose  TenYearCHD
# 4235       84.0     86.0           0
# 4236       86.0      NaN           0
# ...

# %%
data.tail(10)
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 4230     0   56        1.0              1         3.0     0.0
# 4231     1   58        3.0              0         0.0     0.0
# 4232     1   68        1.0              0         0.0     0.0
# 4233     1   50        1.0              1         1.0     0.0
# 4234     1   51        3.0              1        43.0     0.0
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
# 4238     1   40        3.0              0         0.0     0.0
# 4239     0   39        3.0              1        30.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 4230                0             1         0    268.0  170.0  102.0  22.89
# 4231                0             1         0    187.0  141.0   81.0  24.96
# ...

# %%
data.head(1)
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39        4.0              0         0.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
#
#    TenYearCHD
# 0           0

# %%
data.drop('age',axis=1,inplace=True)

# %%
data.head(1)
# Out:
#    male  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1        4.0              0         0.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
#
#    TenYearCHD
# 0           0

# %%
data.drop(['currentSmoker','cigsPerDay'],axis=1,inplace=True)

# %%
data.head(1)
# Out:
#    male  education  BPMeds  prevalentStroke  prevalentHyp  diabetes  totChol  \
# 0     1        4.0     0.0                0             0         0    195.0
#
#    sysBP  diaBP    BMI  heartRate  glucose  TenYearCHD
# 0  106.0   70.0  26.97       80.0     77.0           0

# %%
data.head()
# Out:
#    male  education  BPMeds  prevalentStroke  prevalentHyp  diabetes  totChol  \
# 0     1        4.0     0.0                0             0         0    195.0
# 1     0        2.0     0.0                0             0         0    250.0
# 2     1        1.0     0.0                0             0         0    245.0
# 3     0        3.0     0.0                0             1         0    225.0
# 4     0        3.0     0.0                0             0         0    285.0
#
#    sysBP  diaBP    BMI  heartRate  glucose  TenYearCHD
# 0  106.0   70.0  26.97       80.0     77.0           0
# 1  121.0   81.0  28.73       95.0     76.0           0
# 2  127.5   80.0  25.34       75.0     70.0           0
# 3  150.0   95.0  28.58       65.0    103.0           1
# 4  130.0   84.0  23.10       85.0     85.0           0

# %%
data.drop(2,inplace=True)

# %%
data.head()
# Out:
#    male  education  BPMeds  prevalentStroke  prevalentHyp  diabetes  totChol  \
# 0     1        4.0     0.0                0             0         0    195.0
# 1     0        2.0     0.0                0             0         0    250.0
# 3     0        3.0     0.0                0             1         0    225.0
# 4     0        3.0     0.0                0             0         0    285.0
# 5     0        2.0     0.0                0             1         0    228.0
#
#    sysBP  diaBP    BMI  heartRate  glucose  TenYearCHD
# 0  106.0   70.0  26.97       80.0     77.0           0
# 1  121.0   81.0  28.73       95.0     76.0           0
# 3  150.0   95.0  28.58       65.0    103.0           1
# 4  130.0   84.0  23.10       85.0     85.0           0
# 5  180.0  110.0  30.30       77.0     99.0           0
