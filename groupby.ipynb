# %%
import pandas as pd

# %%
data=pd.read_csv('framingham.csv')

# %%
data
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
# 4238     1   40        3.0              0         0.0     0.0
# 4239     0   39        3.0              1        30.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %%
import numpy as np
data1=data.groupby('male').agg({'age':np.mean}).reset_index()

# %%
data1
# Out:
#    male        age
# 0     0  49.795868
# 1     1  49.293407

# %%
data2=data.groupby(['male','currentSmoker']).agg({'heartRate':np.mean,'cigsPerDay':np.mean}).reset_index()

# %%
data2
# Out:
#    male  currentSmoker  heartRate  cigsPerDay
# 0     0              0  76.576520    0.000000
# 1     0              1  77.852376   14.147844
# 2     1              0  72.243697    0.000000
# 3     1              1  75.558371   22.109890

# %%
data2=data.groupby(['male','currentSmoker']).agg({'heartRate':np.mean,'cigsPerDay':max}).reset_index()

# %%
data2
# Out:
#    male  currentSmoker  heartRate  cigsPerDay
# 0     0              0  76.576520         0.0
# 1     0              1  77.852376        50.0
# 2     1              0  72.243697         0.0
# 3     1              1  75.558371        70.0

# %%
data2=data.groupby(['male','currentSmoker']).agg({'heartRate':np.mean,'cigsPerDay':min}).reset_index()

# %%
data2
# Out:
#    male  currentSmoker  heartRate  cigsPerDay
# 0     0              0  76.576520         0.0
# 1     0              1  77.852376         1.0
# 2     1              0  72.243697         0.0
# 3     1              1  75.558371         1.0

# %%
data2.to_csv('result.csv',index=False)
