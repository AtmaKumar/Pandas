# %%
import pandas as pd

# %%
data=pd.read_csv("framingham.csv")

# %%
data.head()
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39        4.0              0         0.0     0.0                0
# 1     0   46        2.0              0         0.0     0.0                0
# 2     1   48        1.0              1        20.0     0.0                0
# 3     0   61        3.0              1        30.0     0.0                0
# 4     0   46        3.0              1        23.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
# 2             0         0    245.0  127.5   80.0  25.34       75.0     70.0
# 3             1         0    225.0  150.0   95.0  28.58       65.0    103.0
# 4             0         0    285.0  130.0   84.0  23.10       85.0     85.0
#
#    TenYearCHD
# 0           0
# 1           0
# ...

# %%
data["education"].min()
# Out:
# 1.0

# %%
data["age"].mean()
# Out:
# 49.58018867924528

# %%
x=data.groupby("education").mean()

# %%
x
# Out:
#                male        age  currentSmoker  cigsPerDay    BPMeds  \
# education
# 1.0        0.451744  51.941860       0.468023    8.683626  0.031324
# 2.0        0.390263  47.255387       0.541899    9.839228  0.030571
# 3.0        0.326560  48.727141       0.467344    8.111111  0.025000
# 4.0        0.583510  48.150106       0.507400    9.510638  0.027837
#
#            prevalentStroke  prevalentHyp  diabetes     totChol       sysBP  \
# education
# 1.0               0.008721      0.361047  0.034884  238.105418  135.849419
# 2.0               0.005587      0.286512  0.018356  235.389159  130.828013
# 3.0               0.004354      0.259797  0.020319  236.580645  129.403483
# 4.0               0.000000      0.270613  0.019027  234.702128  128.117336
#
#                diaBP        BMI  heartRate    glucose  TenYearCHD
# education
# 1.0        83.897384  26.567461  76.085515  83.080153    0.187791
# 2.0        82.325219  25.313732  76.718276  81.020390    0.117318
# ...

# %%
x.to_csv("data1.csv")

# %%
data.head()
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39        4.0              0         0.0     0.0                0
# 1     0   46        2.0              0         0.0     0.0                0
# 2     1   48        1.0              1        20.0     0.0                0
# 3     0   61        3.0              1        30.0     0.0                0
# 4     0   46        3.0              1        23.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
# 2             0         0    245.0  127.5   80.0  25.34       75.0     70.0
# 3             1         0    225.0  150.0   95.0  28.58       65.0    103.0
# 4             0         0    285.0  130.0   84.0  23.10       85.0     85.0
#
#    TenYearCHD
# 0           0
# 1           0
# ...

# %%
data.query('diabetes==1')
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 37       1   52        1.0              0         0.0     0.0
# 44       0   53        3.0              0         0.0     1.0
# 56       0   54        1.0              1         9.0     0.0
# 66       0   62        1.0              0         0.0     0.0
# 96       0   63        4.0              1        20.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4096     0   56        1.0              0         0.0     0.0
# 4154     1   52        2.0              0         0.0     0.0
# 4203     1   63        1.0              1        10.0     0.0
# 4215     0   63        1.0              0         0.0     0.0
# 4228     0   50        1.0              0         0.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 37                  0             1         1    178.0  160.0   98.0  40.11
# ...

# %%
data[data["diabetes"]==1]
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 37       1   52        1.0              0         0.0     0.0
# 44       0   53        3.0              0         0.0     1.0
# 56       0   54        1.0              1         9.0     0.0
# 66       0   62        1.0              0         0.0     0.0
# 96       0   63        4.0              1        20.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4096     0   56        1.0              0         0.0     0.0
# 4154     1   52        2.0              0         0.0     0.0
# 4203     1   63        1.0              1        10.0     0.0
# 4215     0   63        1.0              0         0.0     0.0
# 4228     0   50        1.0              0         0.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 37                  0             1         1    178.0  160.0   98.0  40.11
# ...

# %%
data[data["diabetes"]==1]["currentSmoker"].value_counts()
# Out:
# 0    70
# 1    39
# Name: currentSmoker, dtype: int64

# %%
data[data["diabetes"]==1]["age"].mean()
# Out:
# 54.92660550458716

# %%
per=39/(39+70)
per
# Out:
# 0.3577981651376147

# %%
data["currentSmoker"].value_counts()
# Out:
# 0    2145
# 1    2095
# Name: currentSmoker, dtype: int64

# %%
per=2095/(2095+2145)
per
# Out:
# 0.49410377358490565

# %%
data["diabetes"].value_counts()
# Out:
# 0    4131
# 1     109
# Name: diabetes, dtype: int64

# %%
k2=data.groupby(["male","currentSmoker"]).mean()

# %%
k2
# Out:
#                           age  education  cigsPerDay    BPMeds  \
# male currentSmoker
# 0    0              51.622642   1.900714    0.000000  0.042674
#      1              47.152679   2.055785   14.147844  0.029713
# 1    0              50.924370   2.082729    0.000000  0.028209
#      1              48.240506   1.947124   22.109890  0.013686
#
#                     prevalentStroke  prevalentHyp  diabetes     totChol  \
# male currentSmoker
# 0    0                     0.008386      0.368274  0.025856  242.775972
#      1                     0.003033      0.221436  0.020222  234.536383
# 1    0                     0.008403      0.337535  0.046218  230.713080
#      1                     0.003617      0.298373  0.017179  234.647913
#
#                          sysBP      diaBP        BMI  heartRate    glucose  \
# male currentSmoker
# 0    0              136.310273  83.896925  26.253563  76.576520  82.740109
# ...

# %%
k2["age"].plot.bar()

# %%
k2["glucose"].plot.bar()

# %%
k2["heartRate"].plot.bar()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.countplot(data["male"])

# %%
k1=data.groupby("male").mean()

# %%
k1
# Out:
#             age  education  currentSmoker  cigsPerDay    BPMeds  \
# male
# 0     49.795868   1.964105       0.408678    5.729730  0.037364
# 1     49.293407   2.000000       0.607692   13.368771  0.019391
#
#       prevalentStroke  prevalentHyp  diabetes     totChol       sysBP  \
# male
# 0            0.006198      0.308264  0.023554  239.441313  133.040083
# 1            0.005495      0.313736  0.028571  233.104799  131.443132
#
#           diaBP        BMI  heartRate   glucose  TenYearCHD
# male
# 0     82.296694  25.510723  77.097934  81.83605    0.124380
# 1     83.696978  26.185333  74.257284  82.12434    0.188462

# %%
k2=k1.T

# %%
k2.head(1)
# Out:
# male          0          1
# age   49.795868  49.293407

# %%
k2=k2.rename(columns={0:"Male",1:"Female"})

# %%
k2
# Out:
# male                   Male      Female
# age               49.795868   49.293407
# education          1.964105    2.000000
# currentSmoker      0.408678    0.607692
# cigsPerDay         5.729730   13.368771
# BPMeds             0.037364    0.019391
# prevalentStroke    0.006198    0.005495
# prevalentHyp       0.308264    0.313736
# diabetes           0.023554    0.028571
# totChol          239.441313  233.104799
# sysBP            133.040083  131.443132
# diaBP             82.296694   83.696978
# BMI               25.510723   26.185333
# heartRate         77.097934   74.257284
# glucose           81.836050   82.124340
# TenYearCHD         0.124380    0.188462

# %%
k10=k2.rename(columns={"Male":"Male1","Female":"Female1"})
k10
# Out:
# male                  Male1     Female1
# age               49.795868   49.293407
# education          1.964105    2.000000
# currentSmoker      0.408678    0.607692
# cigsPerDay         5.729730   13.368771
# BPMeds             0.037364    0.019391
# prevalentStroke    0.006198    0.005495
# prevalentHyp       0.308264    0.313736
# diabetes           0.023554    0.028571
# totChol          239.441313  233.104799
# sysBP            133.040083  131.443132
# diaBP             82.296694   83.696978
# BMI               25.510723   26.185333
# heartRate         77.097934   74.257284
# glucose           81.836050   82.124340
# TenYearCHD         0.124380    0.188462

# %%
k2=k2.rename(index={"male":"feature"})

# %%
k2.to_csv("Mann_for_Male.csv")

# %%
data.groupby(["currentSmoker"]).mean()
# Out:
#                    male        age  education  cigsPerDay    BPMeds  \
# currentSmoker
# 0              0.332867  51.390210   1.960747    0.000000  0.037825
# 1              0.527924  47.726969   1.998534   18.356244  0.021236
#
#                prevalentStroke  prevalentHyp  diabetes     totChol  \
# currentSmoker
# 0                     0.008392      0.358042  0.032634  238.741769
# 1                     0.003341      0.262053  0.018616  234.595930
#
#                     sysBP      diaBP        BMI  heartRate    glucose  \
# currentSmoker
# 0              135.191142  84.168065  26.478289  75.134266  83.297146
# 1              129.450358  81.597136  25.108712  76.641834  80.579365
#
#                TenYearCHD
# currentSmoker
# 0                0.144988
# 1                0.158950

# %%
data.groupby("male").mean()
# Out:
#             age  education  currentSmoker  cigsPerDay    BPMeds  \
# male
# 0     49.795868   1.964105       0.408678    5.729730  0.037364
# 1     49.293407   2.000000       0.607692   13.368771  0.019391
#
#       prevalentStroke  prevalentHyp  diabetes     totChol       sysBP  \
# male
# 0            0.006198      0.308264  0.023554  239.441313  133.040083
# 1            0.005495      0.313736  0.028571  233.104799  131.443132
#
#           diaBP        BMI  heartRate   glucose  TenYearCHD
# male
# 0     82.296694  25.510723  77.097934  81.83605    0.124380
# 1     83.696978  26.185333  74.257284  82.12434    0.188462

# %%
data.groupby("male").max()
# Out:
#       age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# male
# 0      70        4.0              1        50.0     1.0                1
# 1      69        4.0              1        70.0     1.0                1
#
#       prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  \
# male
# 0                1         1    600.0  295.0  142.5  56.80      143.0
# 1                1         1    696.0  235.0  136.0  40.38      125.0
#
#       glucose  TenYearCHD
# male
# 0       394.0           1
# 1       394.0           1

# %%
data.groupby("male").min()
# Out:
#       age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# male
# 0      32        1.0              0         0.0     0.0                0
# 1      33        1.0              0         0.0     0.0                0
#
#       prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  \
# male
# 0                0         0    107.0   83.5   50.0  15.96       46.0
# 1                0         0    113.0   83.5   48.0  15.54       44.0
#
#       glucose  TenYearCHD
# male
# 0        40.0           0
# 1        40.0           0

# %%
data.groupby("currentSmoker").max()
# Out:
#                male  age  education  cigsPerDay  BPMeds  prevalentStroke  \
# currentSmoker
# 0                 1   70        4.0         0.0     1.0                1
# 1                 1   69        4.0        70.0     1.0                1
#
#                prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# currentSmoker
# 0                         1         1    600.0  295.0  142.5  56.80
# 1                         1         1    696.0  230.0  130.0  44.27
#
#                heartRate  glucose  TenYearCHD
# currentSmoker
# 0                  143.0    394.0           1
# 1                  130.0    368.0           1

# %%
data.groupby("currentSmoker").min()
# Out:
#                male  age  education  cigsPerDay  BPMeds  prevalentStroke  \
# currentSmoker
# 0                 0   33        1.0         0.0     0.0                0
# 1                 0   32        1.0         1.0     0.0                0
#
#                prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# currentSmoker
# 0                         0         0    107.0   85.5   51.0  15.54
# 1                         0         0    113.0   83.5   48.0  15.96
#
#                heartRate  glucose  TenYearCHD
# currentSmoker
# 0                   44.0     40.0           0
# 1                   45.0     40.0           0

# %%
data.groupby("currentSmoker").min().age
# Out:
# currentSmoker
# 0    33
# 1    32
# Name: age, dtype: int64
